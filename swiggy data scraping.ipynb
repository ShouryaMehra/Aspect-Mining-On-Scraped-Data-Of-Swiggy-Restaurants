# %%
# Importing required libraries
import pandas as pd
import json
import re
import selenium
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager  
from string import punctuation
from textblob import TextBlob, Word
import math
from nltk import sent_tokenize, word_tokenize, PorterStemmer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import en_core_web_lg
nlp = en_core_web_lg.load()

# %% [markdown]
# ## Scraping data from Swiggy

# %%
driver = webdriver.Chrome(executable_path='C:\driver\chromedriver.exe')
driver.get('https://www.swiggy.com/restaurants/voosh-thalis-and-bowls-indiranagar-bangalore-365812')

# %%
encoded_data = driver.find_elements_by_class_name("_2wg_t")

# %%
raw_data = [] 
for data in range(len(encoded_data)):
    raw_data.append(encoded_data[data].text)

# %%
desc=[]
Scraped_database = []
for i in range(len(raw_data)):
    dict_1={}
    x = raw_data[i].split("\n",10)
    if 'Bestseller' in x:
        dict_1['Bestseller'] = "Bestseller"
        dict_1['Must Try'] = ""
    else:
        if 'Must Try' in x:
            dict_1['Must Try'] = "Must Try"
            dict_1['Bestseller'] = ""
        else:    
            dict_1['Bestseller'] = ""
            dict_1['Must Try'] = ""
    if 'Bestseller' in x:
        x.remove("Bestseller")
    if "Must Try" in x:
        x.remove("Must Try")
    dict_1['Item_name'] = x[0]
    dict_1['Price'] = x[1]
    if len(x[2]) > 3:
        dict_1['Description'] = x[2]
        desc.append(x[2])
    else: 
        dict_1['Description'] = ""
    Scraped_database.append(dict_1)

# %%
# Extracted infromation of food products from swiggy
# categories available
'''
    tags = Bestseller, Must Try
    Item_name
    Price
    Description
'''

Scraped_database
# Out:
# [{'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Homely Bhindi Masala Thali with Sweet',
#   'Price': '189',
#   'Description': 'Enjoy a delicious meal with bhindi masala, dal tadka, 2 phulkas, rice and sweet. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Homely Dal Tadka Thali with Sweet, Roti or Rice',
#   'Price': '189',
#   'Description': 'Enjoy a delicious meal with dal tadka, dry veggie of the day, 2 phulkas, rice, raita and sweet. Amazing for one.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Homely Paneer Masala Thali with Sweet',
#   'Price': '194',
#   'Description': 'Enjoy a delicious meal with paneer masala, dal tadka, 2 phulkas, rice and sweet. Amazing for one.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Voosh Variety Thali with a Sweet & Butter Milk',
#   'Price': '199',
#   'Description': 'Treat yourself with delicious bhindi Masala, aloo gobhi, dal tadka, 2 phulka, rice ,sweet, butter milk. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Voosh Paneer Premium Thali with Sweet, Butter Milk',
#   'Price': '209',
#   'Description': 'Enjoy a wholesome thali meal with paneer masala, dry veggie of the day, dal tadka, 2 phulkas, rice, sweet, butter milk. Amazing for one.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Homely Egg Masala Thali with Sweet',
#   'Price': '189',
#   'Description': 'Enjoy a delicious meal with Egg masala, dal tadka, 2 phulkas, rice and sweet. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Homely Bhindi Masala Thali with Sweet',
#   'Price': '189',
#   'Description': 'Enjoy a delicious meal with bhindi masala, dal tadka, 2 phulkas, rice and sweet. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Homely Dal Tadka Thali with Sweet, Roti or Rice',
#   'Price': '189',
#   'Description': 'Enjoy a delicious meal with dal tadka, dry veggie of the day, 2 phulkas, rice, raita and sweet. Amazing for one.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Homely Paneer Masala Thali with Sweet',
#   'Price': '194',
#   'Description': 'Enjoy a delicious meal with paneer masala, dal tadka, 2 phulkas, rice and sweet. Amazing for one.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Voosh Variety Thali with a Sweet & Butter Milk',
#   'Price': '199',
#   'Description': 'Treat yourself with delicious bhindi Masala, aloo gobhi, dal tadka, 2 phulka, rice ,sweet, butter milk. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Voosh Paneer Premium Thali with Sweet, Butter Milk',
#   'Price': '209',
#   'Description': 'Enjoy a wholesome thali meal with paneer masala, dry veggie of the day, dal tadka, 2 phulkas, rice, sweet, butter milk. Amazing for one.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Homely Egg Masala Thali with Sweet',
#   'Price': '189',
#   'Description': 'Enjoy a delicious meal with Egg masala, dal tadka, 2 phulkas, rice and sweet. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Voosh Egg Premium Thali with Sweet, Butter Milk',
#   'Price': '209',
#   'Description': 'Enjoy a wholesome thali meal with egg Masala, dry veggie of the day, dal tadka, 2 phulkas, rice , sweet , butter milk. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Homely Chicken Masala Thali with Sweet',
#   'Price': '204',
#   'Description': 'Enjoy a delicious meal with chicken masala, dal tadka, 2 phulkas, rice and sweet. Amazing for one.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Voosh Chicken Premium Thali with Sweet, Buttermilk',
#   'Price': '219',
#   'Description': 'Enjoy a wholesome thali meal with chicken masala, dry veggie of the day, dal tadka, 2 phulkas, rice , sweet , butter milk. Amazing for one.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': '2 Aloo Onion Paratha, Curd & Pickle Meal',
#   'Price': '189',
#   'Description': '2 aloo onion parathas, curd, sweet, salad and pickle. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': '2 Aloo Paratha, Curd & Pickle Meal',
#   'Price': '189',
#   'Description': '2 aloo parathas, curd, sweet, salad and pickle. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': '2 Gobhi Paratha, Curd & Pickle Meal',
#   'Price': '189',
#   'Description': '2 gobhi parathas, curd, sweet, salad and pickle. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': '2 Paneer Paratha, Curd & Pickle Meal',
#   'Price': '199',
#   'Description': '2 paneer parathas, curd, sweet, salad and pickle. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Voosh Paratha Platter with Butter Milk',
#   'Price': '219',
#   'Description': 'Enjoy a delicious meal of paneer paratha(1 piece), aloo paratha(1 piece), paneer masala, sweet, butter milk, salad or pickle. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Healthy Dal Khichidi with Pickle & Salad',
#   'Price': '129',
#   'Description': 'The most homely meal ever made. Dal khichdi is healthy, light and tasty. Healthy for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Onion Tomato Kichidi with Pickle & Salad',
#   'Price': '129',
#   'Description': 'Healthiness meets tanginess. A flavorful mix of dal khichdi and freshly chopped onion and tomatoes. Healthy meal for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Garlic Lasooni Khichdi with Bhindi Masala & Pickle',
#   'Price': '139',
#   'Description': 'A classic combination of lasooni dal khichdi and bhindi masala. You may miss your mom after eating this. Healthy meal for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Garlic Lasooni Khichdi with Aloo Gobhi & Pickle',
#   'Price': '139',
#   'Description': 'A classic combination of lasooni dal khichdi and aloo gobhi. You may miss your mom after eating this. Healthy meal for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Healthy Dal Khichidi with Bhindi Masala & Pickle',
#   'Price': '139',
#   'Description': 'A classic combination of healthy dal khichdi and bhindi masala. You may miss your mom after eating this. Healthy meal for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Onion Tomato Kichidi with Bhindi Masala & Pickle',
#   'Price': '139',
#   'Description': 'A classic combination of lasooni dal khichdi and bhindi masala. You may miss your mom after eating this. Healthy meal for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Onion Tomato Kichidi Thali with Aloo Gobi & Pickle',
#   'Price': '139',
#   'Description': 'A classic combination of lasooni dal khichdi and aloo gobhi. You may miss your mom after eating this. Healthy meal for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Garlic Khichidi, Cucumber Salad & 1 Boiled Egg',
#   'Price': '149',
#   'Description': 'Unavailable'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Healthy Dal Khichdi, Cucumber Salad & 1 Boiled Egg',
#   'Price': '149',
#   'Description': 'Power food combo with healthy dal khichdi, cucumber cachumber salad and a boiled egg. This meal is perfect for gaining a powerful dose of health and nutrition.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Lasooni Khichdi, Chickpea Salad, 1 Boiled Egg',
#   'Price': '149',
#   'Description': 'Unavailable'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Healthy Dal Khichdi, Chickpea Salad, 1 Boiled Egg',
#   'Price': '149',
#   'Description': 'Power food combo with healthy dal khichidi with pickle, cucumber cachumber salad and a boiled egg. This meal is perfect for gaining a powerful dose of health and nutrition.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Onion Tomato Khichdi, Chickpea Salad, 1 Boiled Egg',
#   'Price': '149',
#   'Description': 'Power food combo with healthy onion tomato dal khichdi, chickpea salad and a boiled egg. This meal is perfect for gaining a powerful dose of health and nutrition.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Dal Tadka Rice Bowl with Butter Milk',
#   'Price': '179',
#   'Description': 'Yummy bowl of dal tadka with steamy hot rice and a refreshing bottle of buttermilk. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Paneer Rice Bowl with a Butter Milk',
#   'Price': '219',
#   'Description': 'Yummy bowl of paneer masala with steamy hot rice and a refreshing bottle of buttermilk. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Egg Masala Rice Bowl with Butter Milk',
#   'Price': '209',
#   'Description': 'Yummy bowl of egg masala with steamy hot rice and a refreshing bottle of buttermilk. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Chicken Masala Rice Bowl with Butter Milk',
#   'Price': '229',
#   'Description': 'Yummy bowl of chicken masala with steamy hot rice and a refreshing bottle of buttermilk. Amazing for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Voosh Family Meal For 2 with 2 Buttermilk',
#   'Price': '399',
#   'Description': 'Paneer masala(250 ml), dry veggie(250 ml), dal tadka(250 ml), 4 phulkas, rice, 2 sweet of the day and 2 butter milk. Amazing for two.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Dal Tadka',
#   'Price': '119',
#   'Description': "Mom's original yellow dal with a vooshified tadka of basic Indian masala alongside fresh coriander leaves. Serves 1 with full Satisfaction."},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Bhindi Masala',
#   'Price': '149',
#   'Description': 'A semi dry sabzi with bhindi cooked in a traditional onion tomato gravy. Serves 1 with full satisfaction.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Aloo Gobhi',
#   'Price': '149',
#   'Description': 'A dry north Indian sabzi with aloo gobhi tossed in basic Indian spices with a splash of fresh aromatic coriander. Serves 1 with full satisfaction.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Paneer Massala',
#   'Price': '200',
#   'Description': 'Fresh paneer tossed in vooshified onion tomato gravy with rich Indian spices and coriander leaves. Serves 1 with full satisfaction!'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Egg Masala',
#   'Price': '189',
#   'Description': 'Fresh boiled egg tossed in Vooshified onion tomato gravy with rich Indian spices and coriander leaves. Serves 1 with full satisfaction!'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Set of Chapatis (2 Chapatis)',
#   'Price': '39',
#   'Description': 'Wheat chapattis - soft, fluffy and cooked to perfection.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Set of Chapatis (4 - Chapatis)',
#   'Price': '49',
#   'Description': 'Wheat chapattis - soft, fluffy and cooked to perfection.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Steamed Rice',
#   'Price': '49',
#   'Description': 'Fresh, aromatic and steamy hot.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Set of 4 Plain Tawa Paratha',
#   'Price': '79',
#   'Description': '4 wheat plain parathas - soft, fluffy and cooked to perfection.'},
#  {'Bestseller': 'Bestseller',
#   'Must Try': '',
#   'Item_name': 'Raita',
#   'Price': '59',
#   'Description': 'Freshly made with crispy cucumber garnishing.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Cucumber Cachumber Salad',
#   'Price': '79',
#   'Description': 'Kachumber is a salad dish in Indian cuisine consisting of fresh chopped tomatoes, cucumbers, onions, lemon juice, and sometimes, chili peppers. Refreshing and healthy for one.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Salad',
#   'Price': '59',
#   'Description': 'Fresh carrot, cucumber, tomato and aromatic coriander garnishing.'},
#  {'Bestseller': '',
#   'Must Try': '',
#   'Item_name': 'Sweet of the Day (1 Piece)',
#   'Price': '39',
#   'Description': 'Fun fact-The idea of having a dessert at the end of a meal goes back to the Romans.'}]

# %% [markdown]
# ## Preprocessing data

# %%
# text cleaning
desc = re.sub('[^A-Za-z]+', ' ', str(desc).strip())
# remove stop words
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(desc) 
filtered_sentence = [w for w in word_tokens if not w in stop_words] 

filtered_sentence = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 
desc = " ".join(filtered_sentence)   
desc
# Out:
# 'Enjoy delicious meal bhindi masala dal tadka phulkas rice sweet Amazing one Enjoy delicious meal dal tadka dry veggie day phulkas rice raita sweet Amazing one Enjoy delicious meal paneer masala dal tadka phulkas rice sweet Amazing one Treat delicious bhindi Masala aloo gobhi dal tadka phulka rice sweet butter milk Amazing one Enjoy wholesome thali meal paneer masala dry veggie day dal tadka phulkas rice sweet butter milk Amazing one Enjoy delicious meal Egg masala dal tadka phulkas rice sweet Amazing one Enjoy delicious meal bhindi masala dal tadka phulkas rice sweet Amazing one Enjoy delicious meal dal tadka dry veggie day phulkas rice raita sweet Amazing one Enjoy delicious meal paneer masala dal tadka phulkas rice sweet Amazing one Treat delicious bhindi Masala aloo gobhi dal tadka phulka rice sweet butter milk Amazing one Enjoy wholesome thali meal paneer masala dry veggie day dal tadka phulkas rice sweet butter milk Amazing one Enjoy delicious meal Egg masala dal tadka phulkas rice sweet Amazing one Enjoy wholesome thali meal egg Masala dry veggie day dal tadka phulkas rice sweet butter milk Amazing one Enjoy delicious meal chicken masala dal tadka phulkas rice sweet Amazing one Enjoy wholesome thali meal chicken masala dry veggie day dal tadka phulkas rice sweet butter milk Amazing one aloo onion parathas curd sweet salad pickle Amazing one aloo parathas curd sweet salad pickle Amazing one gobhi parathas curd sweet salad pickle Amazing one paneer parathas curd sweet salad pickle Amazing one Enjoy delicious meal paneer paratha piece aloo paratha piece paneer masala sweet butter milk salad pickle Amazing one The homely meal ever made Dal khichdi healthy light tasty Healthy one Healthiness meets tanginess A flavorful mix dal khichdi freshly chopped onion tomatoes Healthy meal one A classic combination lasooni dal khichdi bhindi masala You may miss mom eating Healthy meal one A classic combination lasooni dal khichdi aloo gobhi You may miss mom eating Healthy meal one A classic combination healthy dal khichdi bhindi masala You may miss mom eating Healthy meal one A classic combination lasooni dal khichdi bhindi masala You may miss mom eating Healthy meal one A classic combination lasooni dal khichdi aloo gobhi You may miss mom eating Healthy meal one Unavailable Power food combo healthy dal khichdi cucumber cachumber salad boiled egg This meal perfect gaining powerful dose health nutrition Unavailable Power food combo healthy dal khichidi pickle cucumber cachumber salad boiled egg This meal perfect gaining powerful dose health nutrition Power food combo healthy onion tomato dal khichdi chickpea salad boiled egg This meal perfect gaining powerful dose health nutrition Yummy bowl dal tadka steamy hot rice refreshing bottle buttermilk Amazing one Yummy bowl paneer masala steamy hot rice refreshing bottle buttermilk Amazing one Yummy bowl egg masala steamy hot rice refreshing bottle buttermilk Amazing one Yummy bowl chicken masala steamy hot rice refreshing bottle buttermilk Amazing one Paneer masala ml dry veggie ml dal tadka ml phulkas rice sweet day butter milk Amazing two Mom original yellow dal vooshified tadka basic Indian masala alongside fresh coriander leaves Serves full Satisfaction A semi dry sabzi bhindi cooked traditional onion tomato gravy Serves full satisfaction A dry north Indian sabzi aloo gobhi tossed basic Indian spices splash fresh aromatic coriander Serves full satisfaction Fresh paneer tossed vooshified onion tomato gravy rich Indian spices coriander leaves Serves full satisfaction Fresh boiled egg tossed Vooshified onion tomato gravy rich Indian spices coriander leaves Serves full satisfaction Wheat chapattis soft fluffy cooked perfection Wheat chapattis soft fluffy cooked perfection Fresh aromatic steamy hot wheat plain parathas soft fluffy cooked perfection Freshly made crispy cucumber garnishing Kachumber salad dish Indian cuisine consisting fresh chopped tomatoes cucumbers onions lemon juice sometime ...

# %% [markdown]
# ## Frequency count

# %%
# functions

def _create_frequency_matrix(sentences):
    frequency_matrix = {}
    stopWords = set(stopwords.words("english"))
#     ps = PorterStemmer()

    for sent in sentences:
        freq_table = {}
        words = word_tokenize(sent)
        for word in words:
            word = word.lower()
#             word = ps.stem(word)
            if word in stopWords:
                continue

            if word in freq_table:
                freq_table[word] += 1
            else:
                freq_table[word] = 1

        frequency_matrix["Words_frequency"] = freq_table

    return frequency_matrix


def _create_tf_matrix(freq_matrix):
    tf_matrix = {}

    for sent, f_table in freq_matrix.items():
        tf_table = {}

        count_words_in_sentence = len(f_table)
        for word, count in f_table.items():
            tf_table[word] = count / count_words_in_sentence

        tf_matrix[sent] = tf_table

    return tf_matrix


def _create_documents_per_words(freq_matrix):
    word_per_doc_table = {}

    for sent, f_table in freq_matrix.items():
        for word, count in f_table.items():
            if word in word_per_doc_table:
                word_per_doc_table[word] += 1
            else:
                word_per_doc_table[word] = 1

    return word_per_doc_table


def _create_idf_matrix(freq_matrix, count_doc_per_words, total_documents):
    idf_matrix = {}

    for sent, f_table in freq_matrix.items():
        idf_table = {}

        for word in f_table.keys():
            idf_table[word] = math.log10(total_documents / float(count_doc_per_words[word]))

        idf_matrix[sent] = idf_table

    return idf_matrix

# %%
sentences = sent_tokenize(desc) # NLTK function to tokenize string
total_documents = len(sentences) # length of words

# %%
# Create the Frequency matrix of the words in each sentence.
Frequent_words = _create_frequency_matrix(sentences)
Frequent_words 

# generate database for visulization
vec=list()
frq=list()
for item in Frequent_words['Words_frequency']:
    vec.append(item)
    frq.append(Frequent_words['Words_frequency'][item])
    
database = pd.DataFrame({"vectors":vec ,"frequency":frq })    

df = database.sort_values(by=['frequency'],ascending=False,ignore_index=True)   #sort data
display(df.head(10))
df.to_excel("database.xlsx",index=False) # save data as excel file
# Out:
#    vectors  frequency
# 0      one         32
# 1      dal         28
# 2     meal         25
# 3  amazing         25
# 4   masala         22
# 5    sweet         21
# 6     rice         20
# 7    tadka         18
# 8    enjoy         14
# 9  phulkas         14

# %%
# Calculate TermFrequency and generate a matrix
TermFeq = _create_tf_matrix(Frequent_words)
TermFeq
# Out:
# {'Words_frequency': {'enjoy': 0.10606060606060606,
#   'delicious': 0.09090909090909091,
#   'meal': 0.1893939393939394,
#   'bhindi': 0.06060606060606061,
#   'masala': 0.16666666666666666,
#   'dal': 0.21212121212121213,
#   'tadka': 0.13636363636363635,
#   'phulkas': 0.10606060606060606,
#   'rice': 0.15151515151515152,
#   'sweet': 0.1590909090909091,
#   'amazing': 0.1893939393939394,
#   'one': 0.24242424242424243,
#   'dry': 0.06818181818181818,
#   'veggie': 0.05303030303030303,
#   'day': 0.05303030303030303,
#   'raita': 0.015151515151515152,
#   'paneer': 0.07575757575757576,
#   'treat': 0.015151515151515152,
#   'aloo': 0.06060606060606061,
#   'gobhi': 0.045454545454545456,
#   'phulka': 0.015151515151515152,
#   'butter': 0.06060606060606061,
#   'milk': 0.06060606060606061,
#   'wholesome': 0.030303030303030304,
#   'thali': 0.030303030303030304,
#   'egg': 0.06060606060606061,
#   'chicken': 0.022727272727272728,
#   'onion': 0.045454545454545456,
#   'parathas': 0.03787878787878788,
#   'curd': 0.030303030303030304,
#   'salad': 0.06818181818181818,
#   'pickle': 0.045454545454545456,
#   'paratha': 0.015151515151515152,
#   'piece': 0.015151515151515152,
#   'homely': 0.007575757575757576,
#   'ever': 0.007575757575757576,
#   'made': 0.015151515151515152,
#   'khichdi': 0.06818181818181818,
#   'healthy': 0.09848484848484848,
#   'light': 0.007575757575757576,
#   'tasty': 0.007575757575757576,
#   'healthiness': 0.007575757575757576,
#   'meets': 0.007575757575757576,
#   'tanginess': 0.007575757575757576,
#   'flavorful': 0.007575757575757576,
#   'mix': 0.007575757575757576,
#   'freshly': 0.015151515151515152,
#   'chopped': 0.015151515151515152,
#   'tomatoes': 0.015151515151515152,
#   'classic': 0.03787878787878788,
#   'combination': 0.03787878787878788,
#   'lasooni': 0.030303030303030304,
#   'may': 0.03787878787878788,
#   'miss': 0.03787878787878788,
#   'mom': 0.045454545454545456,
#   'eating': 0.03787878787878788,
#   'unavailable': 0.015151515151515152,
#   'power': 0.022727272727272728,
#   'food': 0.022727272727272728,
#   'combo': 0.022727272727272728,
#   'cucumber': 0.030303030303030304,
#   'cachumber': 0.015151515151515152,
#   'boiled': 0.030303030303030304,
#   'perfect': 0.022727272727272728,
#   'gaining': 0.022727272727272728,
#   'powerful': 0.022727272727272728,
#   'dose': 0.022727272727272728,
#   'health': 0.022727272727272728,
#   'nutrition': 0.022727272727272728,
#   'khichidi': 0.007575757575757576,
#   'tomato': 0.03787878787878788,
#   'chickpea': 0.007575757575757576,
#   'yummy': 0.030303030303030304,
#   'bowl': 0.030303030303030304,
#   'steamy': 0.03787878787878788,
#   'hot': 0.03787878787878788,
#   'refreshing': 0.03787878787878788,
#   'bottle': 0.030303030303030304,
#   'buttermilk': 0.030303030303030304,
#   'ml': 0.022727272727272728,
#   'two': 0.007575757575757576,
#   'original': 0.007575757575757576,
#   'yellow': 0.007575757575757576,
#   'vooshified': 0.022727272727272728,
#   'basic': 0.015151515151515152,
#   'indian': 0.045454545454545456,
#   'alongside': 0.007575757575757576,
#   'fresh': 0.05303030303030303,
#   'coriander': 0.03787878787878788,
#   'leaves': 0.022727272727272728,
#   'serves': 0.03787878787878788,
#   'full': 0.03787878787878788,
#   'satisfaction': 0.03787878787878788,
#   'semi': 0.007575757575757576,
#   'sabzi': 0.015151515151515152,
#   'cooked': 0.030303030303030304,
#   'traditional': 0.007575757575757576,
#   'gravy': 0.022727272727272728,
#   'north': 0.007575757575757576,
#   'tossed': 0.022727272727272728,
#   'spices': 0.022727272727272728,
#   'splash': 0.007575757575757576,
#   'aromatic': 0.022727272727272728,
#   'rich': 0.015151515151515152,
#   'wheat': 0.022727272727272728,
#   'chapattis': 0.015151515151515152,
#   'soft': 0.022727272727272728,
#   'fluffy': 0.022727272727272728,
#   'perfection': 0.022727272727272728,
#   'plain': 0.007575757575757576,
#   'crispy': 0.007575757575757576,
#   'garnishing': 0.015151515151515152,
#   'kachumber': 0.007575757575757576,
#   'dish': 0.007575757575757576,
#   'cuisine': 0.007575757575757576,
#   'consisting': 0.007575757575757576,
#   'cucumbers': 0.007575757575757576,
#   'onions': 0.007575757575757576,
#   'lemon': 0.007575757575757576,
#   'juice': 0.007575757575757576,
#   'sometimes': 0.007575757575757576,
#   'chili': 0.007575757575757576,
#   'peppers': 0.007575757575757576,
#   'carrot': 0.007575757575757576,
#   'fun': 0.007575757575757576,
#   'fact': 0.007575757575757576,
#   'idea': 0.007575757575757576,
#   'dessert': 0.007575757575757576,
#   'end': 0.007575757575757576,
#   'goes': 0.007575757575757576,
#   'back': 0.007575757575757576,
#   'romans': 0.007575757575757576}}

# %% [markdown]
# ## Top aspects from descriptions

# %%
"""Create a list of common words to remove"""

stop_words = stopwords.words('english')   
"""Define a function to extract keywords"""
def get_aspects(x):
    doc=nlp(x) ## Tokenize and extract grammatical components
    doc=[i.text for i in doc if i.text not in stop_words and i.pos_=="NOUN"] ## Remove common words and retain only nouns
    doc=list(map(lambda i: i.lower(),doc)) ## Normalize text to lower case
    doc=pd.Series(doc) 
    doc=doc.value_counts().head(50).index.tolist() ## Get top most frequent nouns
    return doc

corpus = get_aspects(str(desc))

# %%
# aspects with Term Frequency score
aspect_name=[]
aspect_score = []
for vec in TermFeq['Words_frequency']:
    if vec in corpus:
        aspect_name.append(vec)
        aspect_score.append(round(TermFeq['Words_frequency'][vec],4))
aspect_df= pd.DataFrame({'Item_name': aspect_name,'Item_Score':aspect_score})
aspect_df = aspect_df.sort_values(by=['Item_Score'],ascending=False,ignore_index=True)
display(aspect_df)
aspect_df.to_excel("aspects.xlsx",index=False) # save as excel
# Out:
#        Item_name  Item_Score
# 0            one      0.2424
# 1            dal      0.2121
# 2           meal      0.1894
# 3         masala      0.1667
# 4           rice      0.1515
# 5          tadka      0.1364
# 6         paneer      0.0758
# 7          salad      0.0682
# 8           aloo      0.0606
# 9         bhindi      0.0606
# 10        butter      0.0606
# 11          milk      0.0606
# 12           egg      0.0606
# 13        veggie      0.0530
# 14           day      0.0530
# 15         onion      0.0455
# 16        pickle      0.0455
# 17         gobhi      0.0455
# 18           mom      0.0455
# 19        tomato      0.0379
# 20     coriander      0.0379
# 21  satisfaction      0.0379
# 22   combination      0.0379
# 23    buttermilk      0.0303
# 24      cucumber      0.0303
# 25         thali      0.0303
# 26          bowl      0.0303
# 27          curd      0.0303
# 28        bottle      0.0303
# 29         combo      0.0227
# 30            ml      0.0227
# 31         wheat      0.0227
# 32        spices      0.0227
# 33         gravy      0.0227
# 34        leaves      0.0227
# 35          dose      0.0227
# 36       chicken      0.0227
# 37          food      0.0227
# 38     nutrition      0.0227
# 39        health      0.0227
# 40    perfection      0.0227
# 41      tomatoes      0.0152
# 42       paratha      0.0152
# 43         piece      0.0152
# 44         sabzi      0.0152
# 45     chapattis      0.0152
# 46        onions      0.0076
# 47   healthiness      0.0076
# 48       cuisine      0.0076
# 49         chili      0.0076

# %%
# # Creating a table for documents per words
# IDF_matrix = _create_documents_per_words(TermFeq)
# IDF_matrix

# %%
# _create_idf_matrix(f2,f3,total_documents)
